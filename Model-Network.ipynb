# %% [markdown]
# # Simple Reinforcement Learning with Tensorflow: Part 3 - Model-Based RL
# In this iPython notebook we implement a policy and model network which work in tandem to solve the CartPole reinforcement learning problem. To learn more, read here: https://medium.com/p/9a6fe0cce99
#
# For more reinforcment learning tutorials, see:
# https://github.com/awjuliani/DeepRL-Agents

# %% [markdown]
# ### Loading libraries and starting CartPole environment

# %%
from __future__ import print_function
import numpy as np
try:
    import cPickle as pickle
except ModuleNotFoundError:
    import pickle
import tensorflow as tf
# %matplotlib inline
import matplotlib.pyplot as plt
import math

# %%
import sys
if sys.version_info.major > 2:
    xrange = range
del sys

# %%
import gym
env = gym.make('CartPole-v0')

# %% [markdown]
# ### Setting Hyper-parameters

# %%
# hyperparameters
H = 8 # number of hidden layer neurons
learning_rate = 1e-2
gamma = 0.99 # discount factor for reward
decay_rate = 0.99 # decay factor for RMSProp leaky sum of grad^2
resume = False # resume from previous checkpoint?

model_bs = 3 # Batch size when learning from model
real_bs = 3 # Batch size when learning from real environment

# model initialization
D = 4 # input dimensionality

# %% [markdown]
# ### Policy Network

# %%
tf.reset_default_graph()
observations = tf.placeholder(tf.float32, [None,4] , name="input_x")
W1 = tf.get_variable("W1", shape=[4, H],
           initializer=tf.contrib.layers.xavier_initializer())
layer1 = tf.nn.relu(tf.matmul(observations,W1))
W2 = tf.get_variable("W2", shape=[H, 1],
           initializer=tf.contrib.layers.xavier_initializer())
score = tf.matmul(layer1,W2)
probability = tf.nn.sigmoid(score)

tvars = tf.trainable_variables()
input_y = tf.placeholder(tf.float32,[None,1], name="input_y")
advantages = tf.placeholder(tf.float32,name="reward_signal")
adam = tf.train.AdamOptimizer(learning_rate=learning_rate)
W1Grad = tf.placeholder(tf.float32,name="batch_grad1")
W2Grad = tf.placeholder(tf.float32,name="batch_grad2")
batchGrad = [W1Grad,W2Grad]
loglik = tf.log(input_y*(input_y - probability) + (1 - input_y)*(input_y + probability))
loss = -tf.reduce_mean(loglik * advantages) 
newGrads = tf.gradients(loss,tvars)
updateGrads = adam.apply_gradients(zip(batchGrad,tvars))

# %% [markdown]
# ### Model Network
# Here we implement a multi-layer neural network that predicts the next observation, reward, and done state from a current state and action.

# %%
mH = 256 # model layer size

input_data = tf.placeholder(tf.float32, [None, 5])
with tf.variable_scope('rnnlm'):
    softmax_w = tf.get_variable("softmax_w", [mH, 50])
    softmax_b = tf.get_variable("softmax_b", [50])

previous_state = tf.placeholder(tf.float32, [None,5] , name="previous_state")
W1M = tf.get_variable("W1M", shape=[5, mH],
           initializer=tf.contrib.layers.xavier_initializer())
B1M = tf.Variable(tf.zeros([mH]),name="B1M")
layer1M = tf.nn.relu(tf.matmul(previous_state,W1M) + B1M)
W2M = tf.get_variable("W2M", shape=[mH, mH],
           initializer=tf.contrib.layers.xavier_initializer())
B2M = tf.Variable(tf.zeros([mH]),name="B2M")
layer2M = tf.nn.relu(tf.matmul(layer1M,W2M) + B2M)
wO = tf.get_variable("wO", shape=[mH, 4],
           initializer=tf.contrib.layers.xavier_initializer())
wR = tf.get_variable("wR", shape=[mH, 1],
           initializer=tf.contrib.layers.xavier_initializer())
wD = tf.get_variable("wD", shape=[mH, 1],
           initializer=tf.contrib.layers.xavier_initializer())

bO = tf.Variable(tf.zeros([4]),name="bO")
bR = tf.Variable(tf.zeros([1]),name="bR")
bD = tf.Variable(tf.ones([1]),name="bD")


predicted_observation = tf.matmul(layer2M,wO,name="predicted_observation") + bO
predicted_reward = tf.matmul(layer2M,wR,name="predicted_reward") + bR
predicted_done = tf.sigmoid(tf.matmul(layer2M,wD,name="predicted_done") + bD)

true_observation = tf.placeholder(tf.float32,[None,4],name="true_observation")
true_reward = tf.placeholder(tf.float32,[None,1],name="true_reward")
true_done = tf.placeholder(tf.float32,[None,1],name="true_done")


predicted_state = tf.concat([predicted_observation,predicted_reward,predicted_done],1)

observation_loss = tf.square(true_observation - predicted_observation)

reward_loss = tf.square(true_reward - predicted_reward)

done_loss = tf.multiply(predicted_done, true_done) + tf.multiply(1-predicted_done, 1-true_done)
done_loss = -tf.log(done_loss)

model_loss = tf.reduce_mean(observation_loss + done_loss + reward_loss)

modelAdam = tf.train.AdamOptimizer(learning_rate=learning_rate)
updateModel = modelAdam.minimize(model_loss)

# %% [markdown]
# ### Helper-functions

# %%
def resetGradBuffer(gradBuffer):
    for ix,grad in enumerate(gradBuffer):
        gradBuffer[ix] = grad * 0
    return gradBuffer
        
def discount_rewards(r):
    """ take 1D float array of rewards and compute discounted reward """
    discounted_r = np.zeros_like(r)
    running_add = 0
    for t in reversed(xrange(0, r.size)):
        running_add = running_add * gamma + r[t]
        discounted_r[t] = running_add
    return discounted_r


# This function uses our model to produce a new state when given a previous state and action
def stepModel(sess, xs, action):
    toFeed = np.reshape(np.hstack([xs[-1][0],np.array(action)]),[1,5])
    myPredict = sess.run([predicted_state],feed_dict={previous_state: toFeed})
    reward = myPredict[0][:,4]
    observation = myPredict[0][:,0:4]
    observation[:,0] = np.clip(observation[:,0],-2.4,2.4)
    observation[:,2] = np.clip(observation[:,2],-0.4,0.4)
    doneP = np.clip(myPredict[0][:,5],0,1)
    if doneP > 0.1 or len(xs)>= 300:
        done = True
    else:
        done = False
    return observation, reward, done

# %% [markdown]
# ## Training the Policy and Model

# %%
xs,drs,ys,ds = [],[],[],[]
running_reward = None
reward_sum = 0
episode_number = 1
real_episodes = 1
init = tf.global_variables_initializer()
batch_size = real_bs

drawFromModel = False # When set to True, will use model for observations
trainTheModel = True # Whether to train the model
trainThePolicy = False # Whether to train the policy
switch_point = 1

# Launch the graph
with tf.Session() as sess:
    rendering = False
    sess.run(init)
    observation = env.reset()
    x = observation
    gradBuffer = sess.run(tvars)
    gradBuffer = resetGradBuffer(gradBuffer)
    
    while episode_number <= 5000:
        # Start displaying environment once performance is acceptably high.
        if (reward_sum/batch_size > 150 and drawFromModel == False) or rendering == True : 
            env.render()
            rendering = True
            
        x = np.reshape(observation,[1,4])

        tfprob = sess.run(probability,feed_dict={observations: x})
        action = 1 if np.random.uniform() < tfprob else 0

        # record various intermediates (needed later for backprop)
        xs.append(x) 
        y = 1 if action == 0 else 0 
        ys.append(y)
        
        # step the  model or real environment and get new measurements
        if drawFromModel == False:
            observation, reward, done, info = env.step(action)
        else:
            observation, reward, done = stepModel(sess,xs,action)
                
        reward_sum += reward
        
        ds.append(done*1)
        drs.append(reward) # record reward (has to be done after we call step() to get reward for previous action)

        if done: 
            
            if drawFromModel == False: 
                real_episodes += 1
            episode_number += 1

            # stack together all inputs, hidden states, action gradients, and rewards for this episode
            epx = np.vstack(xs)
            epy = np.vstack(ys)
            epr = np.vstack(drs)
            epd = np.vstack(ds)
            xs,drs,ys,ds = [],[],[],[] # reset array memory
            
            if trainTheModel == True:
                actions = np.array([np.abs(y-1) for y in epy][:-1])
                state_prevs = epx[:-1,:]
                state_prevs = np.hstack([state_prevs,actions])
                state_nexts = epx[1:,:]
                rewards = np.array(epr[1:,:])
                dones = np.array(epd[1:,:])
                state_nextsAll = np.hstack([state_nexts,rewards,dones])

                feed_dict={previous_state: state_prevs, true_observation: state_nexts,true_done:dones,true_reward:rewards}
                loss,pState,_ = sess.run([model_loss,predicted_state,updateModel],feed_dict)
            if trainThePolicy == True:
                discounted_epr = discount_rewards(epr).astype('float32')
                discounted_epr -= np.mean(discounted_epr)
                discounted_epr /= np.std(discounted_epr)
                tGrad = sess.run(newGrads,feed_dict={observations: epx, input_y: epy, advantages: discounted_epr})
                
                # If gradients becom too large, end training process
                if np.sum(tGrad[0] == tGrad[0]) == 0:
                    break
                for ix,grad in enumerate(tGrad):
                    gradBuffer[ix] += grad
                
            if switch_point + batch_size == episode_number: 
                switch_point = episode_number
                if trainThePolicy == True:
                    sess.run(updateGrads,feed_dict={W1Grad: gradBuffer[0],W2Grad:gradBuffer[1]})
                    gradBuffer = resetGradBuffer(gradBuffer)

                running_reward = reward_sum if running_reward is None else running_reward * 0.99 + reward_sum * 0.01
                if drawFromModel == False:
                    print('World Perf: Episode %f. Reward %f. action: %f. mean reward %f.' % (real_episodes,reward_sum/real_bs,action, running_reward/real_bs))
                    if reward_sum/batch_size > 200:
                        break
                reward_sum = 0

                # Once the model has been trained on 100 episodes, we start alternating between training the policy
                # from the model and training the model from the real environment.
                if episode_number > 100:
                    drawFromModel = not drawFromModel
                    trainTheModel = not trainTheModel
                    trainThePolicy = not trainThePolicy
            
            if drawFromModel == True:
                observation = np.random.uniform(-0.1,0.1,[4]) # Generate reasonable starting point
                batch_size = model_bs
            else:
                observation = env.reset()
                batch_size = real_bs
                
print(real_episodes)
# Out:
# World Perf: Episode 4.000000. Reward 20.333333. action: 1.000000. mean reward 20.333333.
# World Perf: Episode 7.000000. Reward 17.000000. action: 0.000000. mean reward 20.300000.
# World Perf: Episode 10.000000. Reward 22.666667. action: 0.000000. mean reward 20.323667.
# World Perf: Episode 13.000000. Reward 14.333333. action: 0.000000. mean reward 20.263763.
# World Perf: Episode 16.000000. Reward 22.000000. action: 0.000000. mean reward 20.281126.
# World Perf: Episode 19.000000. Reward 25.000000. action: 0.000000. mean reward 20.328314.
# World Perf: Episode 22.000000. Reward 26.666667. action: 1.000000. mean reward 20.391698.
# World Perf: Episode 25.000000. Reward 13.000000. action: 0.000000. mean reward 20.317781.
# World Perf: Episode 28.000000. Reward 16.333333. action: 1.000000. mean reward 20.277937.
# World Perf: Episode 31.000000. Reward 27.333333. action: 1.000000. mean reward 20.348490.
# World Perf: Episode 34.000000. Reward 14.666667. action: 1.000000. mean reward 20.291672.
# World Perf: Episode 37.000000. Reward 24.333333. action: 0.000000. mean reward 20.332089.
# World Perf: Episode 40.000000. Reward 16.666667. action: 1.000000. mean reward 20.295435.
# World Perf: Episode 43.000000. Reward 15.666667. action: 1.000000. mean reward 20.249147.
# World Perf: Episode 46.000000. Reward 16.666667. action: 1.000000. mean reward 20.213322.
# World Perf: Episode 49.000000. Reward 15.333333. action: 1.000000. mean reward 20.164522.
# World Perf: Episode 52.000000. Reward 17.000000. action: 1.000000. mean reward 20.132877.
# World Perf: Episode 55.000000. Reward 19.000000. action: 1.000000. mean reward 20.121548.
# World Perf: Episode 58.000000. Reward 22.333333. action: 0.000000. mean reward 20.143666.
# World Perf: Episode 61.000000. Reward 17.000000. action: 1.000000. mean reward 20.112229.
# World Perf: Episode 64.000000. Reward 18.000000. action: 1.000000. mean reward 20.091107.
# World Perf: Episode 67.000000. Reward 20.666667. action: 0.000000. mean reward 20.096863.
# World Perf: Episode 70.000000. Reward 22.666667. action: 0.000000. mean reward 20.122561.
# World Perf: Episode 73.000000. Reward 25.000000. action: 1.000000. mean reward 20.171335.
# World Perf: Episode 76.000000. Reward 13.000000. action: 1.000000. mean reward 20.099622.
# World Perf: Episode 79.000000. Reward 19.000000. action: 0.000000. mean reward 20.088626.
# World Perf: Episode 82.000000. Reward 13.000000. action: 0.000000. mean reward 20.017739.
# World Perf: Episode 85.000000. Reward 18.333333. action: 1.000000. mean reward 20.000895.
# World Perf: Episode 88.000000. Reward 31.666667. action: 0.000000. mean reward 20.117553.
# World Perf: Episode 91.000000. Reward 21.666667. action: 0.000000. mean reward 20.133044.
# World Perf: Episode 94.000000. Reward 18.333333. action: 1.000000. mean reward 20.115047.
# World Perf: Episode 97.000000. Reward 18.000000. action: 1.000000. mean reward 20.093897.
# World Perf: Episode 100.000000. Reward 13.333333. action: 1.000000. mean reward 20.026291.
# World Perf: Episode 103.000000. Reward 21.000000. action: 1.000000. mean reward 20.036028.
# World Perf: Episode 106.000000. Reward 15.666667. action: 0.000000. mean reward 19.920527.
# World Perf: Episode 109.000000. Reward 23.333333. action: 0.000000. mean reward 19.833300.
# World Perf: Episode 112.000000. Reward 9.666667. action: 0.000000. mean reward 19.736046.
# World Perf: Episode 115.000000. Reward 15.333333. action: 0.000000. mean reward 19.542349.
# World Perf: Episode 118.000000. Reward 23.666667. action: 1.000000. mean reward 19.526680.
# World Perf: Episode 121.000000. Reward 17.333333. action: 1.000000. mean reward 19.385561.
# World Perf: Episode 124.000000. Reward 15.000000. action: 1.000000. mean reward 19.289597.
# World Perf: Episode 127.000000. Reward 31.000000. action: 0.000000. mean reward 19.319590.
# World Perf: Episode 130.000000. Reward 20.666667. action: 0.000000. mean reward 19.293879.
# World Perf: Episode 133.000000. Reward 33.000000. action: 0.000000. mean reward 19.403759.
# World Perf: Episode 136.000000. Reward 26.000000. action: 1.000000. mean reward 19.461863.
# World Perf: Episode 139.000000. Reward 24.000000. action: 0.000000. mean reward 19.627323.
# World Perf: Episode 142.000000. Reward 19.333333. action: 1.000000. mean reward 19.523760.
# World Perf: Episode 145.000000. Reward 20.333333. action: 0.000000. mean reward 19.507130.
# World Perf: Episode 148.000000. Reward 23.333333. action: 0.000000. mean reward 19.505232.
# World Perf: Episode 151.000000. Reward 31.666667. action: 0.000000. mean reward 19.549900.
# World Perf: Episode 154.000000. Reward 30.000000. action: 0.000000. mean reward 19.560152.
# World Perf: Episode 157.000000. Reward 13.000000. action: 0.000000. mean reward 19.403933.
# World Perf: Episode 160.000000. Reward 30.000000. action: 0.000000. mean reward 20.113594.
# World Perf: Episode 163.000000. Reward 19.333333. action: 1.000000. mean reward 20.872738.
# World Perf: Episode 166.000000. Reward 27.000000. action: 0.000000. mean reward 21.606623.
# World Perf: Episode 169.000000. Reward 26.666667. action: 1.000000. mean reward 21.687731.
# World Perf: Episode 172.000000. Reward 26.000000. action: 1.000000. mean reward 21.767744.
# World Perf: Episode 175.000000. Reward 40.333333. action: 0.000000. mean reward 21.987244.
# World Perf: Episode 178.000000. Reward 47.000000. action: 1.000000. mean reward 22.463104.
# World Perf: Episode 181.000000. Reward 45.333333. action: 1.000000. mean reward 22.570730.
# World Perf: Episode 184.000000. Reward 40.000000. action: 1.000000. mean reward 22.606117.
# World Perf: Episode 187.000000. Reward 13.666667. action: 0.000000. mean reward 22.443323.
# World Perf: Episode 190.000000. Reward 26.666667. action: 0.000000. mean reward 22.446800.
# World Perf: Episode 193.000000. Reward 10.333333. action: 1.000000. mean reward 22.486116.
# World Perf: Episode 196.000000. Reward 23.333333. action: 1.000000. mean reward 22.342207.
# World Perf: Episode 199.000000. Reward 30.000000. action: 1.000000. mean reward 22.324753.
# World Perf: Episode 202.000000. Reward 24.666667. action: 1.000000. mean reward 22.305235.
# World Perf: Episode 205.000000. Reward 27.666667. action: 1.000000. mean reward 22.200300.
# World Perf: Episode 208.000000. Reward 24.333333. action: 0.000000. mean reward 22.059313.
# World Perf: Episode 211.000000. Reward 28.000000. action: 0.000000. mean reward 22.567709.
# World Perf: Episode 214.000000. Reward 37.000000. action: 0.000000. mean reward 25.483582.
# World Perf: Episode 217.000000. Reward 42.333333. action: 0.000000. mean reward 25.450319.
# World Perf: Episode 220.000000. Reward 15.000000. action: 0.000000. mean reward 28.033808.
# World Perf: Episode 223.000000. Reward 42.666667. action: 1.000000. mean reward 28.184774.
# World Perf: Episode 226.000000. Reward 32.000000. action: 1.000000. mean reward 30.197943.
# World Perf: Episode 229.000000. Reward 31.666667. action: 0.000000. mean reward 30.476675.
# World Perf: Episode 232.000000. Reward 34.333333. action: 1.000000. mean reward 30.313475.
# World Perf: Episode 235.000000. Reward 27.333333. action: 0.000000. mean reward 30.057611.
# World Perf: Episode 238.000000. Reward 17.666667. action: 1.000000. mean reward 29.682840.
# World Perf: Episode 241.000000. Reward 24.000000. action: 1.000000. mean reward 29.385515.
# World Perf: Episode 244.000000. Reward 15.666667. action: 0.000000. mean reward 29.030846.
# World Perf: Episode 247.000000. Reward 34.333333. action: 0.000000. mean reward 28.848158.
# World Perf: Episode 250.000000. Reward 56.333333. action: 1.000000. mean reward 28.939394.
# World Perf: Episode 253.000000. Reward 30.333333. action: 0.000000. mean reward 28.717646.
# World Perf: Episode 256.000000. Reward 33.333333. action: 1.000000. mean reward 28.541258.
# World Perf: Episode 259.000000. Reward 34.000000. action: 0.000000. mean reward 35.183281.
# World Perf: Episode 262.000000. Reward 46.333333. action: 1.000000. mean reward 41.178223.
# World Perf: Episode 265.000000. Reward 27.000000. action: 1.000000. mean reward 40.686230.
# World Perf: Episode 268.000000. Reward 24.666667. action: 1.000000. mean reward 40.507122.
# World Perf: Episode 271.000000. Reward 51.000000. action: 0.000000. mean reward 40.274651.
# World Perf: Episode 274.000000. Reward 23.000000. action: 1.000000. mean reward 39.832741.
# World Perf: Episode 277.000000. Reward 35.666667. action: 1.000000. mean reward 39.458046.
# World Perf: Episode 280.000000. Reward 29.333333. action: 0.000000. mean reward 39.036217.
# World Perf: Episode 283.000000. Reward 52.666667. action: 0.000000. mean reward 43.343185.
# World Perf: Episode 286.000000. Reward 41.333333. action: 1.000000. mean reward 45.670303.
# World Perf: Episode 289.000000. Reward 27.666667. action: 1.000000. mean reward 46.808964.
# World Perf: Episode 292.000000. Reward 33.333333. action: 1.000000. mean reward 46.568405.
# World Perf: Episode 295.000000. Reward 27.000000. action: 1.000000. mean reward 46.073105.
# World Perf: Episode 298.000000. Reward 35.000000. action: 0.000000. mean reward 45.587223.
# World Perf: Episode 301.000000. Reward 32.333333. action: 0.000000. mean reward 45.114681.
# World Perf: Episode 304.000000. Reward 32.333333. action: 0.000000. mean reward 44.718723.
# World Perf: Episode 307.000000. Reward 39.333333. action: 0.000000. mean reward 44.481060.
# World Perf: Episode 310.000000. Reward 22.000000. action: 0.000000. mean reward 43.930874.
# World Perf: Episode 313.000000. Reward 21.333333. action: 1.000000. mean reward 43.423996.
# World Perf: Episode 316.000000. Reward 20.666667. action: 1.000000. mean reward 42.847488.
# World Perf: Episode 319.000000. Reward 22.333333. action: 0.000000. mean reward 43.226627.
# World Perf: Episode 322.000000. Reward 44.666667. action: 1.000000. mean reward 42.910782.
# World Perf: Episode 325.000000. Reward 24.333333. action: 1.000000. mean reward 43.052505.
# World Perf: Episode 328.000000. Reward 29.000000. action: 1.000000. mean reward 42.561100.
# World Perf: Episode 331.000000. Reward 30.666667. action: 0.000000. mean reward 42.152500.
# World Perf: Episode 334.000000. Reward 29.666667. action: 0.000000. mean reward 43.440708.
# World Perf: Episode 337.000000. Reward 80.666667. action: 1.000000. mean reward 43.471054.
# World Perf: Episode 340.000000. Reward 28.333333. action: 1.000000. mean reward 43.005920.
# World Perf: Episode 343.000000. Reward 49.666667. action: 1.000000. mean reward 42.700062.
# World Perf: Episode 346.000000. Reward 24.333333. action: 1.000000. mean reward 42.215099.
# World Perf: Episode 349.000000. Reward 50.000000. action: 1.000000. mean reward 41.953167.
# World Perf: Episode 352.000000. Reward 60.000000. action: 0.000000. mean reward 41.783264.
# World Perf: Episode 355.000000. Reward 32.333333. action: 1.000000. mean reward 41.464123.
# World Perf: Episode 358.000000. Reward 40.666667. action: 0.000000. mean reward 41.123203.
# World Perf: Episode 361.000000. Reward 25.000000. action: 0.000000. mean reward 40.622177.
# World Perf: Episode 364.000000. Reward 22.666667. action: 0.000000. mean reward 40.137043.
# World Perf: Episode 367.000000. Reward 21.000000. action: 1.000000. mean reward 39.701370.
# World Perf: Episode 370.000000. Reward 22.666667. action: 0.000000. mean reward 39.265762.
# World Perf: Episode 373.000000. Reward 26.666667. action: 0.000000. mean reward 38.837029.
# World Perf: Episode 376.000000. Reward 27.000000. action: 0.000000. mean reward 39.085255.
# World Perf: Episode 379.000000. Reward 21.000000. action: 0.000000. mean reward 38.927631.
# World Perf: Episode 382.000000. Reward 50.666667. action: 0.000000. mean reward 41.176762.
# World Perf: Episode 385.000000. Reward 29.666667. action: 0.000000. mean reward 41.527821.
# World Perf: Episode 388.000000. Reward 57.000000. action: 0.000000. mean reward 41.380543.
# World Perf: Episode 391.000000. Reward 46.000000. action: 0.000000. mean reward 41.185455.
# World Perf: Episode 394.000000. Reward 25.000000. action: 1.000000. mean reward 40.809193.
# World Perf: Episode 397.000000. Reward 21.000000. action: 1.000000. mean reward 40.324612.
# World Perf: Episode 400.000000. Reward 36.666667. action: 1.000000. mean reward 40.406494.
# World Perf: Episode 403.000000. Reward 54.000000. action: 0.000000. mean reward 40.379910.
# World Perf: Episode 406.000000. Reward 28.333333. action: 0.000000. mean reward 39.996353.
# World Perf: Episode 409.000000. Reward 40.333333. action: 1.000000. mean reward 39.789631.
# World Perf: Episode 412.000000. Reward 38.333333. action: 0.000000. mean reward 39.568188.
# World Perf: Episode 415.000000. Reward 22.000000. action: 1.000000. mean reward 39.083847.
# World Perf: Episode 418.000000. Reward 50.666667. action: 1.000000. mean reward 39.044556.
# World Perf: Episode 421.000000. Reward 26.666667. action: 0.000000. mean reward 38.741650.
# World Perf: Episode 424.000000. Reward 23.666667. action: 1.000000. mean reward 41.026199.
# World Perf: Episode 427.000000. Reward 56.000000. action: 0.000000. mean reward 43.535862.
# World Perf: Episode 430.000000. Reward 55.000000. action: 0.000000. mean reward 43.351017.
# World Perf: Episode 433.000000. Reward 44.000000. action: 1.000000. mean reward 43.125092.
# World Perf: Episode 436.000000. Reward 31.333333. action: 0.000000. mean reward 42.769749.
# World Perf: Episode 439.000000. Reward 30.666667. action: 1.000000. mean reward 42.332409.
# World Perf: Episode 442.000000. Reward 26.333333. action: 1.000000. mean reward 41.913342.
# World Perf: Episode 445.000000. Reward 55.333333. action: 1.000000. mean reward 41.824535.
# World Perf: Episode 448.000000. Reward 45.333333. action: 0.000000. mean reward 41.618172.
# World Perf: Episode 451.000000. Reward 30.333333. action: 1.000000. mean reward 43.581043.
# World Perf: Episode 454.000000. Reward 40.333333. action: 1.000000. mean reward 44.583012.
# World Perf: Episode 457.000000. Reward 24.666667. action: 0.000000. mean reward 44.156418.
# World Perf: Episode 460.000000. Reward 25.000000. action: 0.000000. mean reward 43.639984.
# World Perf: Episode 463.000000. Reward 62.333333. action: 0.000000. mean reward 43.537338.
# World Perf: Episode 466.000000. Reward 46.666667. action: 1.000000. mean reward 43.177090.
# World Perf: Episode 469.000000. Reward 54.000000. action: 1.000000. mean reward 43.762100.
# World Perf: Episode 472.000000. Reward 24.333333. action: 0.000000. mean reward 43.230061.
# World Perf: Episode 475.000000. Reward 57.000000. action: 0.000000. mean reward 43.699886.
# World Perf: Episode 478.000000. Reward 58.333333. action: 0.000000. mean reward 43.662281.
# World Perf: Episode 481.000000. Reward 28.666667. action: 0.000000. mean reward 43.733505.
# World Perf: Episode 484.000000. Reward 97.333333. action: 1.000000. mean reward 43.877300.
# World Perf: Episode 487.000000. Reward 29.000000. action: 0.000000. mean reward 43.384487.
# World Perf: Episode 490.000000. Reward 47.666667. action: 0.000000. mean reward 43.035168.
# World Perf: Episode 493.000000. Reward 42.666667. action: 1.000000. mean reward 42.730637.
# World Perf: Episode 496.000000. Reward 63.666667. action: 1.000000. mean reward 42.563801.
# World Perf: Episode 499.000000. Reward 21.333333. action: 0.000000. mean reward 44.941113.
# World Perf: Episode 502.000000. Reward 35.666667. action: 1.000000. mean reward 44.442005.
# World Perf: Episode 505.000000. Reward 45.000000. action: 1.000000. mean reward 44.064575.
# World Perf: Episode 508.000000. Reward 28.666667. action: 1.000000. mean reward 43.513092.
# World Perf: Episode 511.000000. Reward 24.000000. action: 1.000000. mean reward 47.387970.
# World Perf: Episode 514.000000. Reward 37.666667. action: 1.000000. mean reward 46.880680.
# World Perf: Episode 517.000000. Reward 49.666667. action: 0.000000. mean reward 46.501957.
# World Perf: Episode 520.000000. Reward 23.666667. action: 1.000000. mean reward 45.877857.
# World Perf: Episode 523.000000. Reward 48.000000. action: 0.000000. mean reward 45.581833.
# World Perf: Episode 526.000000. Reward 40.333333. action: 0.000000. mean reward 48.435932.
# World Perf: Episode 529.000000. Reward 86.000000. action: 1.000000. mean reward 48.398815.
# World Perf: Episode 532.000000. Reward 41.000000. action: 1.000000. mean reward 48.584904.
# World Perf: Episode 535.000000. Reward 28.666667. action: 0.000000. mean reward 48.254475.
# World Perf: Episode 538.000000. Reward 60.333333. action: 1.000000. mean reward 48.044483.
# World Perf: Episode 541.000000. Reward 93.000000. action: 1.000000. mean reward 48.292450.
# World Perf: Episode 544.000000. Reward 57.333333. action: 1.000000. mean reward 48.385178.
# World Perf: Episode 547.000000. Reward 67.333333. action: 0.000000. mean reward 48.313061.
# World Perf: Episode 550.000000. Reward 110.333333. action: 0.000000. mean reward 48.801800.
# World Perf: Episode 553.000000. Reward 53.333333. action: 1.000000. mean reward 48.502819.
# World Perf: Episode 556.000000. Reward 40.333333. action: 1.000000. mean reward 48.058670.
# World Perf: Episode 559.000000. Reward 48.000000. action: 1.000000. mean reward 47.666672.
# World Perf: Episode 562.000000. Reward 46.333333. action: 1.000000. mean reward 47.455837.
# World Perf: Episode 565.000000. Reward 65.666667. action: 1.000000. mean reward 47.454556.
# World Perf: Episode 568.000000. Reward 44.666667. action: 1.000000. mean reward 47.875736.
# World Perf: Episode 571.000000. Reward 30.666667. action: 1.000000. mean reward 47.756653.
# World Perf: Episode 574.000000. Reward 56.000000. action: 1.000000. mean reward 47.652973.
# World Perf: Episode 577.000000. Reward 41.666667. action: 1.000000. mean reward 47.405773.
# World Perf: Episode 580.000000. Reward 38.000000. action: 1.000000. mean reward 47.527248.
# World Perf: Episode 583.000000. Reward 40.666667. action: 1.000000. mean reward 47.651447.
# World Perf: Episode 586.000000. Reward 56.333333. action: 0.000000. mean reward 49.692627.
# World Perf: Episode 589.000000. Reward 33.666667. action: 0.000000. mean reward 49.313168.
# World Perf: Episode 592.000000. Reward 54.000000. action: 0.000000. mean reward 49.635761.
# World Perf: Episode 595.000000. Reward 54.666667. action: 1.000000. mean reward 50.497410.
# World Perf: Episode 598.000000. Reward 56.333333. action: 1.000000. mean reward 50.237030.
# World Perf: Episode 601.000000. Reward 74.666667. action: 1.000000. mean reward 51.484241.
# World Perf: Episode 604.000000. Reward 59.333333. action: 1.000000. mean reward 51.240086.
# World Perf: Episode 607.000000. Reward 32.333333. action: 1.000000. mean reward 50.695038.
# World Perf: Episode 610.000000. Reward 70.333333. action: 0.000000. mean reward 50.595978.
# World Perf: Episode 613.000000. Reward 54.666667. action: 1.000000. mean reward 50.762630.
# World Perf: Episode 616.000000. Reward 34.333333. action: 0.000000. mean reward 51.077015.
# World Perf: Episode 619.000000. Reward 91.666667. action: 1.000000. mean reward 51.538265.
# World Perf: Episode 622.000000. Reward 72.000000. action: 1.000000. mean reward 51.387615.
# World Perf: Episode 625.000000. Reward 32.000000. action: 1.000000. mean reward 50.865696.
# World Perf: Episode 628.000000. Reward 39.000000. action: 1.000000. mean reward 50.435627.
# World Perf: Episode 631.000000. Reward 71.333333. action: 1.000000. mean reward 50.266567.
# World Perf: Episode 634.000000. Reward 93.333333. action: 1.000000. mean reward 50.353252.
# World Perf: Episode 637.000000. Reward 40.333333. action: 0.000000. mean reward 49.860081.
# World Perf: Episode 640.000000. Reward 55.666667. action: 1.000000. mean reward 51.528591.
# World Perf: Episode 643.000000. Reward 29.666667. action: 1.000000. mean reward 50.936310.
# World Perf: Episode 646.000000. Reward 39.333333. action: 1.000000. mean reward 50.409912.
# World Perf: Episode 649.000000. Reward 44.666667. action: 0.000000. mean reward 50.110901.
# World Perf: Episode 652.000000. Reward 113.000000. action: 1.000000. mean reward 50.386898.
# World Perf: Episode 655.000000. Reward 59.333333. action: 1.000000. mean reward 50.260426.
# World Perf: Episode 658.000000. Reward 81.666667. action: 1.000000. mean reward 50.419437.
# World Perf: Episode 661.000000. Reward 157.333333. action: 0.000000. mean reward 51.959518.
# World Perf: Episode 664.000000. Reward 180.333333. action: 1.000000. mean reward 52.890121.
# World Perf: Episode 667.000000. Reward 45.333333. action: 1.000000. mean reward 52.436169.
# World Perf: Episode 670.000000. Reward 95.000000. action: 0.000000. mean reward 52.588993.
# World Perf: Episode 673.000000. Reward 86.000000. action: 1.000000. mean reward 52.517746.
# World Perf: Episode 676.000000. Reward 83.333333. action: 1.000000. mean reward 52.484356.
# World Perf: Episode 679.000000. Reward 61.000000. action: 0.000000. mean reward 52.160908.
# World Perf: Episode 682.000000. Reward 142.333333. action: 0.000000. mean reward 52.800678.
# World Perf: Episode 685.000000. Reward 105.333333. action: 1.000000. mean reward 52.938786.
# World Perf: Episode 688.000000. Reward 36.666667. action: 1.000000. mean reward 52.479080.
# World Perf: Episode 691.000000. Reward 85.666667. action: 1.000000. mean reward 55.529644.
# World Perf: Episode 694.000000. Reward 84.666667. action: 0.000000. mean reward 56.348877.
# World Perf: Episode 697.000000. Reward 45.000000. action: 1.000000. mean reward 55.859665.
# World Perf: Episode 700.000000. Reward 88.333333. action: 0.000000. mean reward 55.782566.
# World Perf: Episode 703.000000. Reward 78.333333. action: 1.000000. mean reward 55.544025.
# World Perf: Episode 706.000000. Reward 58.333333. action: 1.000000. mean reward 58.064686.
# World Perf: Episode 709.000000. Reward 72.000000. action: 1.000000. mean reward 59.099468.
# World Perf: Episode 712.000000. Reward 47.666667. action: 1.000000. mean reward 58.582302.
# World Perf: Episode 715.000000. Reward 34.000000. action: 0.000000. mean reward 57.894878.
# World Perf: Episode 718.000000. Reward 46.333333. action: 1.000000. mean reward 59.229870.
# World Perf: Episode 721.000000. Reward 106.000000. action: 0.000000. mean reward 59.438152.
# World Perf: Episode 724.000000. Reward 72.000000. action: 0.000000. mean reward 61.736160.
# World Perf: Episode 727.000000. Reward 99.666667. action: 0.000000. mean reward 62.213917.
# World Perf: Episode 730.000000. Reward 41.000000. action: 1.000000. mean reward 61.483517.
# World Perf: Episode 733.000000. Reward 75.000000. action: 1.000000. mean reward 61.196060.
# World Perf: Episode 736.000000. Reward 96.000000. action: 0.000000. mean reward 61.037640.
# World Perf: Episode 739.000000. Reward 72.666667. action: 0.000000. mean reward 60.746532.
# World Perf: Episode 742.000000. Reward 115.333333. action: 1.000000. mean reward 60.755550.
# World Perf: Episode 745.000000. Reward 97.000000. action: 1.000000. mean reward 63.708118.
# World Perf: Episode 748.000000. Reward 124.333333. action: 1.000000. mean reward 63.783951.
# World Perf: Episode 751.000000. Reward 105.666667. action: 1.000000. mean reward 63.826420.
# World Perf: Episode 754.000000. Reward 34.000000. action: 0.000000. mean reward 63.170444.
# World Perf: Episode 757.000000. Reward 104.333333. action: 0.000000. mean reward 63.033863.
# World Perf: Episode 760.000000. Reward 87.666667. action: 1.000000. mean reward 62.783382.
# World Perf: Episode 763.000000. Reward 129.666667. action: 1.000000. mean reward 64.884750.
# World Perf: Episode 766.000000. Reward 92.333333. action: 1.000000. mean reward 64.618950.
# World Perf: Episode 769.000000. Reward 66.000000. action: 0.000000. mean reward 64.078194.
# World Perf: Episode 772.000000. Reward 133.666667. action: 1.000000. mean reward 66.127281.
# World Perf: Episode 775.000000. Reward 91.000000. action: 1.000000. mean reward 65.818932.
# World Perf: Episode 778.000000. Reward 91.666667. action: 1.000000. mean reward 65.603691.
# World Perf: Episode 781.000000. Reward 65.666667. action: 0.000000. mean reward 67.890823.
# World Perf: Episode 784.000000. Reward 77.666667. action: 1.000000. mean reward 70.256233.
# World Perf: Episode 787.000000. Reward 124.666667. action: 1.000000. mean reward 70.360527.
# World Perf: Episode 790.000000. Reward 117.000000. action: 1.000000. mean reward 73.438820.
# World Perf: Episode 793.000000. Reward 58.000000. action: 1.000000. mean reward 73.238609.
# World Perf: Episode 796.000000. Reward 104.333333. action: 1.000000. mean reward 72.990593.
# World Perf: Episode 799.000000. Reward 104.666667. action: 1.000000. mean reward 74.623787.
# World Perf: Episode 802.000000. Reward 46.000000. action: 0.000000. mean reward 74.814339.
# World Perf: Episode 805.000000. Reward 90.333333. action: 1.000000. mean reward 74.424072.
# World Perf: Episode 808.000000. Reward 85.000000. action: 1.000000. mean reward 74.142113.
# World Perf: Episode 811.000000. Reward 69.666667. action: 1.000000. mean reward 74.508118.
# World Perf: Episode 814.000000. Reward 59.666667. action: 1.000000. mean reward 73.867233.
# World Perf: Episode 817.000000. Reward 40.000000. action: 1.000000. mean reward 73.438187.
# World Perf: Episode 820.000000. Reward 68.666667. action: 1.000000. mean reward 73.754776.
# World Perf: Episode 823.000000. Reward 95.000000. action: 1.000000. mean reward 73.387222.
# World Perf: Episode 826.000000. Reward 136.333333. action: 1.000000. mean reward 73.398491.
# World Perf: Episode 829.000000. Reward 69.333333. action: 0.000000. mean reward 72.927803.
# World Perf: Episode 832.000000. Reward 125.000000. action: 1.000000. mean reward 72.858711.
# World Perf: Episode 835.000000. Reward 73.333333. action: 1.000000. mean reward 72.271782.
# World Perf: Episode 838.000000. Reward 40.000000. action: 0.000000. mean reward 72.127403.
# World Perf: Episode 841.000000. Reward 65.333333. action: 1.000000. mean reward 71.437111.
# World Perf: Episode 844.000000. Reward 89.666667. action: 1.000000. mean reward 70.995178.
# World Perf: Episode 847.000000. Reward 101.333333. action: 0.000000. mean reward 70.728577.
# World Perf: Episode 850.000000. Reward 109.333333. action: 0.000000. mean reward 73.131226.
# World Perf: Episode 853.000000. Reward 94.000000. action: 0.000000. mean reward 73.642662.
# World Perf: Episode 856.000000. Reward 73.666667. action: 0.000000. mean reward 73.581627.
# World Perf: Episode 859.000000. Reward 53.333333. action: 1.000000. mean reward 74.004677.
# World Perf: Episode 862.000000. Reward 98.333333. action: 1.000000. mean reward 76.403709.
# World Perf: Episode 865.000000. Reward 115.333333. action: 1.000000. mean reward 76.511856.
# World Perf: Episode 868.000000. Reward 104.333333. action: 1.000000. mean reward 78.510170.
# World Perf: Episode 871.000000. Reward 94.000000. action: 1.000000. mean reward 80.871971.
# World Perf: Episode 874.000000. Reward 57.666667. action: 0.000000. mean reward 80.241798.
# World Perf: Episode 877.000000. Reward 119.000000. action: 1.000000. mean reward 80.015503.
# World Perf: Episode 880.000000. Reward 80.000000. action: 1.000000. mean reward 82.175392.
# World Perf: Episode 883.000000. Reward 84.666667. action: 1.000000. mean reward 81.478081.
# World Perf: Episode 886.000000. Reward 80.000000. action: 1.000000. mean reward 80.828331.
# World Perf: Episode 889.000000. Reward 54.000000. action: 0.000000. mean reward 82.559677.
# World Perf: Episode 892.000000. Reward 56.000000. action: 1.000000. mean reward 81.638374.
# World Perf: Episode 895.000000. Reward 108.333333. action: 1.000000. mean reward 81.315323.
# World Perf: Episode 898.000000. Reward 88.666667. action: 0.000000. mean reward 82.280754.
# World Perf: Episode 901.000000. Reward 42.333333. action: 0.000000. mean reward 81.317848.
# World Perf: Episode 904.000000. Reward 31.333333. action: 1.000000. mean reward 82.103897.
# World Perf: Episode 907.000000. Reward 59.333333. action: 1.000000. mean reward 81.431900.
# World Perf: Episode 910.000000. Reward 120.666667. action: 1.000000. mean reward 81.434341.
# World Perf: Episode 913.000000. Reward 75.000000. action: 1.000000. mean reward 81.139900.
# World Perf: Episode 916.000000. Reward 46.666667. action: 0.000000. mean reward 80.312202.
# World Perf: Episode 919.000000. Reward 78.000000. action: 1.000000. mean reward 82.121498.
# World Perf: Episode 922.000000. Reward 75.000000. action: 0.000000. mean reward 81.439705.
# World Perf: Episode 925.000000. Reward 128.333333. action: 1.000000. mean reward 85.003777.
# World Perf: Episode 928.000000. Reward 36.000000. action: 0.000000. mean reward 83.862473.
# World Perf: Episode 931.000000. Reward 98.000000. action: 0.000000. mean reward 83.295448.
# World Perf: Episode 934.000000. Reward 100.000000. action: 1.000000. mean reward 83.903244.
# World Perf: Episode 937.000000. Reward 90.666667. action: 1.000000. mean reward 83.277779.
# World Perf: Episode 940.000000. Reward 145.333333. action: 0.000000. mean reward 83.244255.
# World Perf: Episode 943.000000. Reward 52.666667. action: 1.000000. mean reward 84.198921.
# World Perf: Episode 946.000000. Reward 71.666667. action: 1.000000. mean reward 84.407310.
# World Perf: Episode 949.000000. Reward 44.666667. action: 1.000000. mean reward 83.327858.
# World Perf: Episode 952.000000. Reward 125.000000. action: 0.000000. mean reward 85.190681.
# World Perf: Episode 955.000000. Reward 81.333333. action: 1.000000. mean reward 85.652107.
# World Perf: Episode 958.000000. Reward 126.000000. action: 1.000000. mean reward 85.394714.
# World Perf: Episode 961.000000. Reward 55.333333. action: 0.000000. mean reward 84.966087.
# World Perf: Episode 964.000000. Reward 140.333333. action: 0.000000. mean reward 84.909248.
# World Perf: Episode 967.000000. Reward 90.333333. action: 1.000000. mean reward 84.346687.
# World Perf: Episode 970.000000. Reward 84.000000. action: 1.000000. mean reward 83.653954.
# World Perf: Episode 973.000000. Reward 133.000000. action: 1.000000. mean reward 84.145996.
# World Perf: Episode 976.000000. Reward 103.333333. action: 1.000000. mean reward 84.220558.
# World Perf: Episode 979.000000. Reward 94.333333. action: 1.000000. mean reward 83.699074.
# World Perf: Episode 982.000000. Reward 104.000000. action: 1.000000. mean reward 84.136086.
# World Perf: Episode 985.000000. Reward 130.000000. action: 1.000000. mean reward 86.967598.
# World Perf: Episode 988.000000. Reward 59.666667. action: 0.000000. mean reward 86.350006.
# World Perf: Episode 991.000000. Reward 100.000000. action: 0.000000. mean reward 85.956810.
# World Perf: Episode 994.000000. Reward 160.000000. action: 0.000000. mean reward 87.309502.
# World Perf: Episode 997.000000. Reward 142.666667. action: 0.000000. mean reward 90.267578.
# World Perf: Episode 1000.000000. Reward 178.333333. action: 1.000000. mean reward 92.027321.
# World Perf: Episode 1003.000000. Reward 49.333333. action: 0.000000. mean reward 91.014946.
# World Perf: Episode 1006.000000. Reward 86.666667. action: 1.000000. mean reward 90.782005.
# World Perf: Episode 1009.000000. Reward 109.666667. action: 1.000000. mean reward 90.493622.
# World Perf: Episode 1012.000000. Reward 46.666667. action: 1.000000. mean reward 90.149902.
# World Perf: Episode 1015.000000. Reward 81.000000. action: 1.000000. mean reward 89.713554.
# World Perf: Episode 1018.000000. Reward 82.333333. action: 1.000000. mean reward 89.576897.
# World Perf: Episode 1021.000000. Reward 55.666667. action: 1.000000. mean reward 89.702026.
# World Perf: Episode 1024.000000. Reward 75.666667. action: 1.000000. mean reward 89.558220.
# World Perf: Episode 1027.000000. Reward 68.666667. action: 1.000000. mean reward 88.678841.
# World Perf: Episode 1030.000000. Reward 117.333333. action: 1.000000. mean reward 89.230865.
# World Perf: Episode 1033.000000. Reward 127.000000. action: 0.000000. mean reward 89.048737.
# World Perf: Episode 1036.000000. Reward 102.666667. action: 1.000000. mean reward 88.903229.
# World Perf: Episode 1039.000000. Reward 93.666667. action: 1.000000. mean reward 88.354301.
# World Perf: Episode 1042.000000. Reward 154.000000. action: 0.000000. mean reward 89.357582.
# World Perf: Episode 1045.000000. Reward 72.000000. action: 0.000000. mean reward 91.630089.
# World Perf: Episode 1048.000000. Reward 87.666667. action: 0.000000. mean reward 93.987144.
# World Perf: Episode 1051.000000. Reward 101.000000. action: 1.000000. mean reward 93.847649.
# World Perf: Episode 1054.000000. Reward 48.666667. action: 1.000000. mean reward 94.768044.
# World Perf: Episode 1057.000000. Reward 77.666667. action: 0.000000. mean reward 94.804070.
# World Perf: Episode 1060.000000. Reward 81.000000. action: 1.000000. mean reward 94.015373.
# World Perf: Episode 1063.000000. Reward 120.666667. action: 0.000000. mean reward 93.786293.
# World Perf: Episode 1066.000000. Reward 200.000000. action: 1.000000. mean reward 94.289421.
# World Perf: Episode 1069.000000. Reward 136.333333. action: 1.000000. mean reward 96.899254.
# World Perf: Episode 1072.000000. Reward 96.000000. action: 1.000000. mean reward 99.107933.
# World Perf: Episode 1075.000000. Reward 91.666667. action: 1.000000. mean reward 98.164177.
# World Perf: Episode 1078.000000. Reward 107.333333. action: 1.000000. mean reward 97.635368.
# World Perf: Episode 1081.000000. Reward 118.333333. action: 1.000000. mean reward 97.083191.
# World Perf: Episode 1084.000000. Reward 129.333333. action: 1.000000. mean reward 98.698662.
# World Perf: Episode 1087.000000. Reward 67.333333. action: 1.000000. mean reward 98.992516.
# World Perf: Episode 1090.000000. Reward 97.333333. action: 1.000000. mean reward 98.185249.
# World Perf: Episode 1093.000000. Reward 101.000000. action: 1.000000. mean reward 97.644768.
# World Perf: Episode 1096.000000. Reward 79.333333. action: 1.000000. mean reward 96.551064.
# World Perf: Episode 1099.000000. Reward 104.000000. action: 1.000000. mean reward 95.937477.
# World Perf: Episode 1102.000000. Reward 110.000000. action: 0.000000. mean reward 95.463768.
# World Perf: Episode 1105.000000. Reward 171.666667. action: 0.000000. mean reward 95.437653.
# World Perf: Episode 1108.000000. Reward 108.666667. action: 0.000000. mean reward 95.071327.
# World Perf: Episode 1111.000000. Reward 98.666667. action: 1.000000. mean reward 97.149239.
# World Perf: Episode 1114.000000. Reward 145.666667. action: 1.000000. mean reward 99.739662.
# World Perf: Episode 1117.000000. Reward 60.666667. action: 0.000000. mean reward 98.576195.
# World Perf: Episode 1120.000000. Reward 89.666667. action: 1.000000. mean reward 98.949135.
# World Perf: Episode 1123.000000. Reward 107.333333. action: 1.000000. mean reward 102.038124.
# World Perf: Episode 1126.000000. Reward 200.000000. action: 1.000000. mean reward 102.172913.
# World Perf: Episode 1129.000000. Reward 88.333333. action: 1.000000. mean reward 104.095886.
# World Perf: Episode 1132.000000. Reward 69.000000. action: 1.000000. mean reward 104.707489.
# World Perf: Episode 1135.000000. Reward 131.666667. action: 0.000000. mean reward 106.001213.
# World Perf: Episode 1138.000000. Reward 101.333333. action: 1.000000. mean reward 107.917015.
# World Perf: Episode 1141.000000. Reward 177.666667. action: 1.000000. mean reward 110.662498.
# World Perf: Episode 1144.000000. Reward 113.666667. action: 0.000000. mean reward 110.407715.
# World Perf: Episode 1147.000000. Reward 90.666667. action: 1.000000. mean reward 112.553520.
# World Perf: Episode 1150.000000. Reward 93.666667. action: 1.000000. mean reward 111.516357.
# World Perf: Episode 1153.000000. Reward 75.333333. action: 0.000000. mean reward 110.191193.
# World Perf: Episode 1156.000000. Reward 170.000000. action: 0.000000. mean reward 112.753166.
# World Perf: Episode 1159.000000. Reward 154.000000. action: 1.000000. mean reward 114.949951.
# World Perf: Episode 1162.000000. Reward 166.333333. action: 1.000000. mean reward 116.682915.
# World Perf: Episode 1165.000000. Reward 110.666667. action: 1.000000. mean reward 118.560371.
# World Perf: Episode 1168.000000. Reward 62.000000. action: 1.000000. mean reward 117.302574.
# World Perf: Episode 1171.000000. Reward 142.333333. action: 0.000000. mean reward 117.490913.
# World Perf: Episode 1174.000000. Reward 134.000000. action: 0.000000. mean reward 118.749702.
# World Perf: Episode 1177.000000. Reward 152.000000. action: 1.000000. mean reward 118.952293.
# World Perf: Episode 1180.000000. Reward 117.333333. action: 1.000000. mean reward 119.630432.
# World Perf: Episode 1183.000000. Reward 87.333333. action: 1.000000. mean reward 121.156303.
# World Perf: Episode 1186.000000. Reward 166.333333. action: 1.000000. mean reward 120.564789.
# World Perf: Episode 1189.000000. Reward 106.333333. action: 0.000000. mean reward 121.363899.
# World Perf: Episode 1192.000000. Reward 103.333333. action: 1.000000. mean reward 123.201263.
# World Perf: Episode 1195.000000. Reward 69.333333. action: 1.000000. mean reward 121.768272.
# World Perf: Episode 1198.000000. Reward 94.666667. action: 1.000000. mean reward 123.374573.
# World Perf: Episode 1201.000000. Reward 120.000000. action: 1.000000. mean reward 123.240608.
# World Perf: Episode 1204.000000. Reward 61.666667. action: 1.000000. mean reward 122.432350.
# World Perf: Episode 1207.000000. Reward 157.666667. action: 1.000000. mean reward 124.002533.
# World Perf: Episode 1210.000000. Reward 147.666667. action: 0.000000. mean reward 125.913231.
# World Perf: Episode 1213.000000. Reward 85.666667. action: 0.000000. mean reward 125.606514.
# World Perf: Episode 1216.000000. Reward 157.333333. action: 0.000000. mean reward 126.193611.
# World Perf: Episode 1219.000000. Reward 164.333333. action: 1.000000. mean reward 126.184654.
# World Perf: Episode 1222.000000. Reward 93.000000. action: 1.000000. mean reward 125.398071.
# World Perf: Episode 1225.000000. Reward 176.333333. action: 0.000000. mean reward 124.915833.
# World Perf: Episode 1228.000000. Reward 125.333333. action: 1.000000. mean reward 126.781853.
# World Perf: Episode 1231.000000. Reward 108.666667. action: 1.000000. mean reward 126.852211.
# World Perf: Episode 1234.000000. Reward 177.000000. action: 0.000000. mean reward 129.689209.
# World Perf: Episode 1237.000000. Reward 130.333333. action: 1.000000. mean reward 131.896454.
# World Perf: Episode 1240.000000. Reward 115.333333. action: 0.000000. mean reward 132.539581.
# World Perf: Episode 1243.000000. Reward 170.666667. action: 0.000000. mean reward 132.153473.
# World Perf: Episode 1246.000000. Reward 129.666667. action: 1.000000. mean reward 133.526291.
# World Perf: Episode 1249.000000. Reward 133.000000. action: 0.000000. mean reward 136.180252.
# World Perf: Episode 1252.000000. Reward 136.000000. action: 1.000000. mean reward 135.048294.
# World Perf: Episode 1255.000000. Reward 120.333333. action: 0.000000. mean reward 133.943130.
# World Perf: Episode 1258.000000. Reward 158.000000. action: 0.000000. mean reward 134.451309.
# World Perf: Episode 1261.000000. Reward 94.000000. action: 0.000000. mean reward 132.856522.
# World Perf: Episode 1264.000000. Reward 142.333333. action: 1.000000. mean reward 131.849243.
# World Perf: Episode 1267.000000. Reward 147.333333. action: 1.000000. mean reward 130.859955.
# World Perf: Episode 1270.000000. Reward 148.666667. action: 0.000000. mean reward 131.778030.
# World Perf: Episode 1273.000000. Reward 122.000000. action: 1.000000. mean reward 130.944870.
# World Perf: Episode 1276.000000. Reward 156.666667. action: 0.000000. mean reward 130.361099.
# World Perf: Episode 1279.000000. Reward 115.666667. action: 1.000000. mean reward 129.130234.
# World Perf: Episode 1282.000000. Reward 136.666667. action: 0.000000. mean reward 128.231857.
# World Perf: Episode 1285.000000. Reward 174.000000. action: 1.000000. mean reward 127.536003.
# World Perf: Episode 1288.000000. Reward 136.000000. action: 0.000000. mean reward 128.436157.
# World Perf: Episode 1291.000000. Reward 103.000000. action: 1.000000. mean reward 129.815445.
# World Perf: Episode 1294.000000. Reward 85.000000. action: 0.000000. mean reward 128.305222.
# World Perf: Episode 1297.000000. Reward 178.000000. action: 0.000000. mean reward 130.383926.
# World Perf: Episode 1300.000000. Reward 153.666667. action: 1.000000. mean reward 132.265396.
# World Perf: Episode 1303.000000. Reward 152.666667. action: 1.000000. mean reward 131.787125.
# World Perf: Episode 1306.000000. Reward 141.333333. action: 0.000000. mean reward 130.704697.
# World Perf: Episode 1309.000000. Reward 105.333333. action: 1.000000. mean reward 129.247299.
# World Perf: Episode 1312.000000. Reward 152.333333. action: 0.000000. mean reward 128.742142.
# World Perf: Episode 1315.000000. Reward 75.000000. action: 1.000000. mean reward 127.355278.
# World Perf: Episode 1318.000000. Reward 120.666667. action: 0.000000. mean reward 126.285835.
# World Perf: Episode 1321.000000. Reward 149.000000. action: 1.000000. mean reward 126.370399.
# World Perf: Episode 1324.000000. Reward 193.000000. action: 0.000000. mean reward 126.245018.
# World Perf: Episode 1327.000000. Reward 106.666667. action: 1.000000. mean reward 124.895477.
# World Perf: Episode 1330.000000. Reward 141.666667. action: 0.000000. mean reward 125.916443.
# World Perf: Episode 1333.000000. Reward 140.000000. action: 1.000000. mean reward 125.165947.
# World Perf: Episode 1336.000000. Reward 195.666667. action: 0.000000. mean reward 124.877907.
# World Perf: Episode 1339.000000. Reward 135.333333. action: 1.000000. mean reward 126.895416.
# World Perf: Episode 1342.000000. Reward 200.000000. action: 1.000000. mean reward 126.456108.
# World Perf: Episode 1345.000000. Reward 110.333333. action: 1.000000. mean reward 128.139145.
# World Perf: Episode 1348.000000. Reward 178.666667. action: 1.000000. mean reward 127.676704.
# World Perf: Episode 1351.000000. Reward 189.000000. action: 1.000000. mean reward 127.421486.
# World Perf: Episode 1354.000000. Reward 133.666667. action: 0.000000. mean reward 126.470009.
# World Perf: Episode 1357.000000. Reward 126.333333. action: 1.000000. mean reward 125.334991.
# World Perf: Episode 1360.000000. Reward 114.666667. action: 0.000000. mean reward 124.995544.
# World Perf: Episode 1363.000000. Reward 127.666667. action: 0.000000. mean reward 124.233917.
# World Perf: Episode 1366.000000. Reward 183.333333. action: 0.000000. mean reward 123.708900.
# World Perf: Episode 1369.000000. Reward 164.666667. action: 1.000000. mean reward 126.017357.
# World Perf: Episode 1372.000000. Reward 107.000000. action: 1.000000. mean reward 124.890755.
# World Perf: Episode 1375.000000. Reward 150.333333. action: 1.000000. mean reward 124.138237.
# World Perf: Episode 1378.000000. Reward 185.666667. action: 1.000000. mean reward 126.236244.
# World Perf: Episode 1381.000000. Reward 144.666667. action: 0.000000. mean reward 125.467384.
# World Perf: Episode 1384.000000. Reward 152.666667. action: 0.000000. mean reward 124.655785.
# World Perf: Episode 1387.000000. Reward 139.666667. action: 0.000000. mean reward 125.620483.
# World Perf: Episode 1390.000000. Reward 112.000000. action: 1.000000. mean reward 125.042137.
# World Perf: Episode 1393.000000. Reward 170.666667. action: 1.000000. mean reward 124.459297.
# World Perf: Episode 1396.000000. Reward 150.333333. action: 0.000000. mean reward 126.485710.
# World Perf: Episode 1399.000000. Reward 132.333333. action: 1.000000. mean reward 128.286987.
# World Perf: Episode 1402.000000. Reward 193.000000. action: 0.000000. mean reward 128.565750.
# World Perf: Episode 1405.000000. Reward 183.666667. action: 0.000000. mean reward 128.132065.
# World Perf: Episode 1408.000000. Reward 94.666667. action: 1.000000. mean reward 129.495789.
# World Perf: Episode 1411.000000. Reward 152.333333. action: 0.000000. mean reward 128.572128.
# World Perf: Episode 1414.000000. Reward 156.666667. action: 0.000000. mean reward 131.427933.
# World Perf: Episode 1417.000000. Reward 200.000000. action: 0.000000. mean reward 133.926010.
# World Perf: Episode 1420.000000. Reward 192.000000. action: 1.000000. mean reward 133.361679.
# World Perf: Episode 1423.000000. Reward 160.333333. action: 1.000000. mean reward 133.858185.
# World Perf: Episode 1426.000000. Reward 141.000000. action: 0.000000. mean reward 133.925583.
# World Perf: Episode 1429.000000. Reward 175.333333. action: 0.000000. mean reward 133.523056.
# World Perf: Episode 1432.000000. Reward 158.333333. action: 0.000000. mean reward 133.978806.
# World Perf: Episode 1435.000000. Reward 134.333333. action: 1.000000. mean reward 133.319168.
# World Perf: Episode 1438.000000. Reward 101.000000. action: 1.000000. mean reward 134.394791.
# World Perf: Episode 1441.000000. Reward 171.666667. action: 1.000000. mean reward 133.648239.
# World Perf: Episode 1444.000000. Reward 123.333333. action: 0.000000. mean reward 132.315125.
# World Perf: Episode 1447.000000. Reward 159.333333. action: 1.000000. mean reward 132.022156.
# World Perf: Episode 1450.000000. Reward 150.333333. action: 0.000000. mean reward 131.173676.
# World Perf: Episode 1453.000000. Reward 107.000000. action: 0.000000. mean reward 129.828354.
# World Perf: Episode 1456.000000. Reward 155.000000. action: 1.000000. mean reward 129.323120.
# World Perf: Episode 1459.000000. Reward 136.333333. action: 1.000000. mean reward 128.350494.
# World Perf: Episode 1462.000000. Reward 137.000000. action: 0.000000. mean reward 127.894707.
# World Perf: Episode 1465.000000. Reward 85.666667. action: 1.000000. mean reward 126.959679.
# World Perf: Episode 1468.000000. Reward 85.666667. action: 1.000000. mean reward 125.427361.
# World Perf: Episode 1471.000000. Reward 144.333333. action: 0.000000. mean reward 124.679604.
# World Perf: Episode 1474.000000. Reward 124.333333. action: 1.000000. mean reward 123.567757.
# World Perf: Episode 1477.000000. Reward 101.333333. action: 0.000000. mean reward 122.233803.
# World Perf: Episode 1480.000000. Reward 112.000000. action: 1.000000. mean reward 123.411537.
# World Perf: Episode 1483.000000. Reward 159.666667. action: 1.000000. mean reward 123.039421.
# World Perf: Episode 1486.000000. Reward 129.666667. action: 1.000000. mean reward 122.687386.
# World Perf: Episode 1489.000000. Reward 153.333333. action: 1.000000. mean reward 124.586128.
# World Perf: Episode 1492.000000. Reward 121.666667. action: 0.000000. mean reward 126.324074.
# World Perf: Episode 1495.000000. Reward 116.333333. action: 0.000000. mean reward 125.149940.
# World Perf: Episode 1498.000000. Reward 108.666667. action: 1.000000. mean reward 123.857910.
# World Perf: Episode 1501.000000. Reward 121.000000. action: 1.000000. mean reward 122.701233.
# World Perf: Episode 1504.000000. Reward 160.000000. action: 0.000000. mean reward 123.120567.
# World Perf: Episode 1507.000000. Reward 130.333333. action: 1.000000. mean reward 122.149254.
# World Perf: Episode 1510.000000. Reward 136.666667. action: 1.000000. mean reward 121.373680.
# World Perf: Episode 1513.000000. Reward 138.333333. action: 1.000000. mean reward 120.594208.
# World Perf: Episode 1516.000000. Reward 144.000000. action: 0.000000. mean reward 121.699135.
# World Perf: Episode 1519.000000. Reward 144.666667. action: 1.000000. mean reward 121.043610.
# World Perf: Episode 1522.000000. Reward 112.666667. action: 1.000000. mean reward 121.106903.
# World Perf: Episode 1525.000000. Reward 188.333333. action: 1.000000. mean reward 121.322960.
# World Perf: Episode 1528.000000. Reward 196.666667. action: 1.000000. mean reward 122.553856.
# World Perf: Episode 1531.000000. Reward 157.333333. action: 1.000000. mean reward 123.145485.
# World Perf: Episode 1534.000000. Reward 173.000000. action: 0.000000. mean reward 122.789757.
# World Perf: Episode 1537.000000. Reward 98.333333. action: 1.000000. mean reward 121.661781.
# World Perf: Episode 1540.000000. Reward 150.666667. action: 1.000000. mean reward 123.777000.
# World Perf: Episode 1543.000000. Reward 181.666667. action: 1.000000. mean reward 124.558571.
# World Perf: Episode 1546.000000. Reward 148.666667. action: 1.000000. mean reward 124.398010.
# World Perf: Episode 1549.000000. Reward 102.000000. action: 1.000000. mean reward 123.198219.
# World Perf: Episode 1552.000000. Reward 171.333333. action: 0.000000. mean reward 122.784966.
# World Perf: Episode 1555.000000. Reward 200.000000. action: 0.000000. mean reward 122.683472.
# World Perf: Episode 1558.000000. Reward 172.000000. action: 1.000000. mean reward 122.381569.
# World Perf: Episode 1561.000000. Reward 166.666667. action: 1.000000. mean reward 125.068001.
# World Perf: Episode 1564.000000. Reward 131.666667. action: 1.000000. mean reward 124.080345.
# World Perf: Episode 1567.000000. Reward 159.666667. action: 0.000000. mean reward 123.362549.
# World Perf: Episode 1570.000000. Reward 133.000000. action: 0.000000. mean reward 123.698242.
# World Perf: Episode 1573.000000. Reward 142.666667. action: 0.000000. mean reward 123.177460.
# World Perf: Episode 1576.000000. Reward 200.000000. action: 1.000000. mean reward 123.993858.
# World Perf: Episode 1579.000000. Reward 141.666667. action: 1.000000. mean reward 126.472435.
# World Perf: Episode 1582.000000. Reward 193.000000. action: 0.000000. mean reward 127.963219.
# World Perf: Episode 1585.000000. Reward 189.333333. action: 0.000000. mean reward 127.608368.
# World Perf: Episode 1588.000000. Reward 153.000000. action: 0.000000. mean reward 126.934540.
# World Perf: Episode 1591.000000. Reward 149.333333. action: 0.000000. mean reward 126.259621.
# World Perf: Episode 1594.000000. Reward 200.000000. action: 0.000000. mean reward 126.364105.
# World Perf: Episode 1597.000000. Reward 192.666667. action: 1.000000. mean reward 125.956795.
# World Perf: Episode 1600.000000. Reward 143.333333. action: 1.000000. mean reward 127.968544.
# World Perf: Episode 1603.000000. Reward 200.000000. action: 0.000000. mean reward 127.744812.
# World Perf: Episode 1606.000000. Reward 200.000000. action: 0.000000. mean reward 127.839531.
# World Perf: Episode 1609.000000. Reward 146.333333. action: 0.000000. mean reward 127.676048.
# World Perf: Episode 1612.000000. Reward 161.666667. action: 1.000000. mean reward 126.937279.
# World Perf: Episode 1615.000000. Reward 153.666667. action: 1.000000. mean reward 128.266632.
# World Perf: Episode 1618.000000. Reward 119.333333. action: 0.000000. mean reward 127.598061.
# World Perf: Episode 1621.000000. Reward 200.000000. action: 0.000000. mean reward 130.525543.
# World Perf: Episode 1624.000000. Reward 132.333333. action: 1.000000. mean reward 130.631241.
# World Perf: Episode 1627.000000. Reward 131.000000. action: 0.000000. mean reward 130.231888.
# World Perf: Episode 1630.000000. Reward 137.000000. action: 1.000000. mean reward 129.418442.
# World Perf: Episode 1633.000000. Reward 146.333333. action: 1.000000. mean reward 131.783981.
# World Perf: Episode 1636.000000. Reward 180.000000. action: 0.000000. mean reward 131.374893.
# World Perf: Episode 1639.000000. Reward 188.666667. action: 1.000000. mean reward 132.075348.
# World Perf: Episode 1642.000000. Reward 200.000000. action: 0.000000. mean reward 133.137741.
# World Perf: Episode 1645.000000. Reward 173.333333. action: 1.000000. mean reward 132.588303.
# World Perf: Episode 1648.000000. Reward 200.000000. action: 1.000000. mean reward 132.273117.
# World Perf: Episode 1651.000000. Reward 181.666667. action: 1.000000. mean reward 133.735565.
# World Perf: Episode 1654.000000. Reward 165.666667. action: 1.000000. mean reward 134.728882.
# World Perf: Episode 1657.000000. Reward 173.666667. action: 0.000000. mean reward 134.201828.
# World Perf: Episode 1660.000000. Reward 140.333333. action: 1.000000. mean reward 135.941360.
# World Perf: Episode 1663.000000. Reward 173.666667. action: 1.000000. mean reward 135.968704.
# World Perf: Episode 1666.000000. Reward 137.333333. action: 0.000000. mean reward 137.280579.
# World Perf: Episode 1669.000000. Reward 135.000000. action: 1.000000. mean reward 139.162659.
# World Perf: Episode 1672.000000. Reward 194.666667. action: 1.000000. mean reward 139.165604.
# World Perf: Episode 1675.000000. Reward 137.000000. action: 1.000000. mean reward 138.585846.
# World Perf: Episode 1678.000000. Reward 171.333333. action: 0.000000. mean reward 141.005188.
# World Perf: Episode 1681.000000. Reward 150.333333. action: 0.000000. mean reward 143.033859.
# World Perf: Episode 1684.000000. Reward 140.666667. action: 1.000000. mean reward 142.166656.
# World Perf: Episode 1687.000000. Reward 175.000000. action: 0.000000. mean reward 141.696091.
# World Perf: Episode 1690.000000. Reward 175.333333. action: 0.000000. mean reward 141.505981.
# World Perf: Episode 1693.000000. Reward 140.000000. action: 1.000000. mean reward 140.901596.
# World Perf: Episode 1696.000000. Reward 160.000000. action: 0.000000. mean reward 141.986359.
# World Perf: Episode 1699.000000. Reward 186.000000. action: 0.000000. mean reward 142.946487.
# World Perf: Episode 1702.000000. Reward 168.333333. action: 1.000000. mean reward 142.071884.
# World Perf: Episode 1705.000000. Reward 182.000000. action: 1.000000. mean reward 144.272446.
# World Perf: Episode 1708.000000. Reward 164.333333. action: 1.000000. mean reward 146.216171.
# World Perf: Episode 1711.000000. Reward 166.333333. action: 1.000000. mean reward 147.242218.
# World Perf: Episode 1714.000000. Reward 191.333333. action: 0.000000. mean reward 146.980606.
# World Perf: Episode 1717.000000. Reward 200.000000. action: 0.000000. mean reward 146.953064.
# World Perf: Episode 1720.000000. Reward 152.000000. action: 1.000000. mean reward 148.631042.
# World Perf: Episode 1723.000000. Reward 94.666667. action: 1.000000. mean reward 150.010315.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-ac0cc7865345> in <module>()
#      24         # Start displaying environment once performance is acceptably high.
#      25         if (reward_sum/batch_size > 150 and drawFromModel == False) or rendering == True :
# ---> 26             env.render()
#      27             rendering = True
#      28
#
# ~\Anaconda3\lib\site-packages\gym\core.py in render(self, mode, close)
#     148             elif mode not in modes:
#     149                 raise error.UnsupportedMode('Unsupported rendering mode: {}. (Supported modes for {}: {})'.format(mode, self, modes))
# --> 150         return self._render(mode=mode, close=close)
#     151
#     152     def close(self):
#
# ~\Anaconda3\lib\site-packages\gym\core.py in _render(self, mode, close)
#     284
#     285     def _render(self, mode='human', close=False):
# --> 286         return self.env.render(mode, close)
#     287
#     288     def _close(self):
#
# ~\Anaconda3\lib\site-packages\gym\core.py in render(self, mode, close)
#     148             elif mode not in modes:
#     149                 raise error.UnsupportedMode('Unsupported rendering mode: {}. (Supported modes for {}: {})'.format(mode, self, modes))
# --> 150         return self._render(mode=mode, close=close)
#     151
#     152     def close(self):
#
# ~\Anaconda3\lib\site-packages\gym\envs\classic_control\cartpole.py in _render(self, mode, close)
#     144         self.poletrans.set_rotation(-x[2])
#     145
# --> 146         return self.viewer.render(return_rgb_array = mode=='rgb_array')
#
# ~\Anaconda3\lib\site-packages\gym\envs\classic_control\rendering.py in render(self, return_rgb_array)
#     102             arr = arr.reshape(buffer.height, buffer.width, 4)
#     103             arr = arr[::-1,:,0:3]
# --> 104         self.window.flip()
#     105         self.onetime_geoms = []
#     106         return arr
#
# ~\Anaconda3\lib\site-packages\pyglet\window\win32\__init__.py in flip(self)
#     309     def flip(self):
#     310         self.draw_mouse_cursor()
# --> 311         self.context.flip()
#     312
#     313     def set_location(self, x, y):
#
# AttributeError: 'NoneType' object has no attribute 'flip'

# %% [markdown]
# ### Checking model representation
# Here we can examine how well the model is able to approximate the true environment after training. The green line indicates the real environment, and the blue indicates model predictions.

# %%
plt.figure(figsize=(8, 12))
for i in range(6):
    plt.subplot(6, 2, 2*i + 1)
    plt.plot(pState[:,i])
    plt.subplot(6,2,2*i+1)
    plt.plot(state_nextsAll[:,i])
plt.tight_layout()
# Out:
# C:\Users\utilisateur\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
